# %% [markdown]
# # Question(s) for Analysis¶
# ### What are the top 10 films that have generated the most profit?
# ### Who are the top 10 directors with the greatest profits?
# ### Which production companies rank in the top 10 for highest profit?
# ### Which ten genres have the highest average vote rating?

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\acer\Downloads\archive (4)\tmdb_5000_movies.csv")

# %%
df.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df["id"].duplicated().any()
# Out:
# False

# %%
print(df.shape)
# Out:
# (4803, 20)

# %%
# printing if any null value present
print(df.isnull().sum())
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
df["tagline"].isnull().sum()
# Out:
# 844

# %%
df["runtime"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4798    False
# 4799    False
# 4800    False
# 4801    False
# 4802    False
# Name: runtime, Length: 4803, dtype: bool

# %%
df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
df.drop(columns=["homepage", "id", "release_date", "status", "keywords", "original_language", "production_countries"], inplace=True)

# %%
df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies     revenue  runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  2787965087    162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   961000000    169.0
# ...

# %%
print(df.isnull().sum())
# Out:
# budget                    0
# genres                    0
# original_title            0
# overview                  3
# popularity                0
# production_companies      0
# revenue                   0
# runtime                   2
# spoken_languages          0
# tagline                 844
# title                     0
# vote_average              0
# vote_count                0
# dtype: int64

# %%
df["original_title"].value_counts()
# Out:
# original_title
# Out of the Blue       2
# Batman                2
# Undiscovered          1
# Beneath Hill 60       1
# The I Inside          1
#                      ..
# Secondhand Lions      1
# The Age of Adaline    1
# Drag Me to Hell       1
# Southpaw              1
# My Date with Drew     1
# Name: count, Length: 4801, dtype: int64

# %% [markdown]
# # What are the top 10 films that have generated the most profit?

# %%
df=pd.DataFrame(df)

# %%
top_10_movies = df[["title", "popularity"]].sort_values(by="popularity", ascending=False).head(10)

# %%
top_10_movies
# Out:
#                                                  title  popularity
# 546                                            Minions  875.581305
# 95                                        Interstellar  724.247784
# 788                                           Deadpool  514.569956
# 94                             Guardians of the Galaxy  481.098624
# 127                                 Mad Max: Fury Road  434.278564
# 28                                      Jurassic World  418.708552
# 199  Pirates of the Caribbean: The Curse of the Bla...  271.972889
# 82                      Dawn of the Planet of the Apes  243.791743
# 200              The Hunger Games: Mockingjay - Part 1  206.227151
# 88                                          Big Hero 6  203.734590

# %%
top_10_revenue_mov= df[["title","revenue"]].sort_values(by="revenue",ascending=False).head(10)

# %%
top_10_revenue_mov
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %% [markdown]
# ### What are the top 10 films that have generated the most profit?

# %%
df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies     revenue  runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  2787965087    162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   961000000    169.0
# ...

# %%
df["gain"]=df["budget"] - df["revenue"]

# %%
profited_movies=df[["title", "gain"]].sort_values(by="gain",ascending=False).head(10)

# %%
profited_movies
# Out:
#                              title       gain
# 13                 The Lone Ranger  165710090
# 135                    The Wolfman  150000000
# 338                      The Alamo  119180039
# 141                Mars Needs Moms  111007242
# 1652          Dragonball Evolution  100000000
# 208               The 13th Warrior   98301101
# 311   The Adventures of Pluto Nash   92896027
# 2638                    Metropolis   91969578
# 467               Mighty Joe Young   90000000
# 376                        Volcano   90000000

# %%
# extract the top 10 movies with the highest total gain

# call the get_top_10_movies function with the DataFrame df
top_10_movies = profited_movies

# define lighter shades of yellow, purple, blue, and orange
light_yellow = '#FFFF99'  # light yellow color
light_purple = '#CC99FF'  # light purple color
light_blue = '#99CCFF'    # light blue color
light_orange = '#FFCC99'  # light orange color

# plotting the data as a horizontal bar plot
plt.figure(figsize=(5, 3))
plt.barh(top_10_movies['title'], top_10_movies['gain'], color=[light_blue, light_yellow, light_purple, light_orange])
plt.xlabel('Gain')
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Total Gain')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Who are the top 10 directors with the greatest profits?

# %%
df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies     revenue  runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  2787965087    162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   961000000    169.0
# ...

# %%
top_10_directors= df[["production_companies", "gain"]].sort_values(by="gain", ascending=False).head(10)

# %%
top_10_directors
# Out:
#                                    production_companies       gain
# 13    [{"name": "Walt Disney Pictures", "id": 2}, {"...  165710090
# 135   [{"name": "Universal Pictures", "id": 33}, {"n...  150000000
# 338   [{"name": "Imagine Entertainment", "id": 23}, ...  119180039
# 141   [{"name": "Walt Disney Animation Studios", "id...  111007242
# 1652  [{"name": "Ingenious Film Partners", "id": 289...  100000000
# 208       [{"name": "Touchstone Pictures", "id": 9195}]   98301101
# 311   [{"name": "Village Roadshow Pictures", "id": 7...   92896027
# 2638  [{"name": "Paramount Pictures", "id": 4}, {"na...   91969578
# 467   [{"name": "Walt Disney Pictures", "id": 2}, {"...   90000000
# 376   [{"name": "Twentieth Century Fox Film Corporat...   90000000

# %%
# extract the top 10 movies with the highest total gain

# call the get_top_10_movies function with the DataFrame df
Top_10_directors = top_10_directors

# define lighter shades of yellow, purple, blue, and orange
light_yellow = '#FFFF99'  # light yellow color
light_purple = '#CC99FF'  # light purple color
light_blue = '#99CCFF'    # light blue color
light_orange = '#FFCC99'  # light orange color

# plotting the data as a horizontal bar plot
plt.figure(figsize=(43, 14))
plt.barh(Top_10_directors['production_companies'], Top_10_directors['gain'], color=[light_blue, light_yellow, light_purple, light_orange])
plt.xlabel('Gain',fontsize=40)
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Total Gain',fontsize=40)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# extract the top 10 movies with the highest total gain

# call the get_top_10_movies function with the DataFrame df
Top_10_directors = top_10_directors

# define lighter shades of yellow, purple, blue, and orange
light_yellow = '#FFFF99'  # light yellow color
light_purple = '#CC99FF'  # light purple color
light_blue = '#99CCFF'    # light blue color
light_orange = '#FFCC99'  # light orange color

# plotting the data as a horizontal bar plot
plt.figure(figsize=(90, 100))
plt.barh(Top_10_directors['production_companies'], Top_10_directors['gain'], color=[light_blue, light_yellow, light_purple, light_orange])
plt.xlabel('Gain',fontsize=100)
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Total Gain',fontsize=100)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Increase the size of y-axis tick labels
plt.tick_params(axis='y', labelsize=90)  
plt.tight_layout()
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_14916\967988477.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Which production companies rank in the top 10 for highest profit?

# %%
df['production_companies'].value_counts()
# Out:
# production_companies
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              351
# ...

# %%
top_10_companies = df.groupby('production_companies')['gain'].sum().sort_values(ascending=False).head(5)
top_10_companies
# Out:
# production_companies
# [{"name": "Walt Disney Pictures", "id": 2}, {"name": "Jerry Bruckheimer Films", "id": 130}, {"name": "Infinitum Nihil", "id": 2691}, {"name": "Silver Bullet Productions (II)", "id": 37380}, {"name": "Blind Wink Productions", "id": 37381}, {"name": "Classic Media", "id": 37382}]                                                           165710090
# [{"name": "Universal Pictures", "id": 33}, {"name": "Stuber Productions", "id": 4403}, {"name": "Relativity Media", "id": 7295}]                                                                                                                                                                                                                 150000000
# ...

# %% [markdown]
# ## Which ten genres have the highest average vote rating?

# %%
df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
#
#                                 production_companies     revenue  runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  2787965087    162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   961000000    169.0
# ...

# %%
top_geners=df[["genres", "vote_count"]].sort_values(by="vote_count",ascending=False).head(10)

# %%
top_geners
# Out:
#                                                 genres  vote_count
# 96   [{"id": 28, "name": "Action"}, {"id": 53, "nam...       13752
# 65   [{"id": 18, "name": "Drama"}, {"id": 28, "name...       12002
# 0    [{"id": 28, "name": "Action"}, {"id": 12, "nam...       11800
# 16   [{"id": 878, "name": "Science Fiction"}, {"id"...       11776
# 788  [{"id": 28, "name": "Action"}, {"id": 12, "nam...       10995
# 95   [{"id": 12, "name": "Adventure"}, {"id": 18, "...       10867
# 287  [{"id": 18, "name": "Drama"}, {"id": 37, "name...       10099
# 94   [{"id": 28, "name": "Action"}, {"id": 878, "na...        9742
# 426  [{"id": 878, "name": "Science Fiction"}, {"id"...        9455
# 127  [{"id": 28, "name": "Action"}, {"id": 12, "nam...        9427

# %%
import matplotlib.pyplot as plt

# Assuming you have already defined your DataFrame and variables like Top_10_directors

# Define different colors for each bar
colors = ['#FF5733', '#33FF57', '#3366FF', '#FF33E9']

# Plotting the data as a horizontal bar plot with different colors
plt.figure(figsize=(43, 14))
plt.barh(Top_10_geners['genres'], Top_10_geners['vote_count'], color=colors)
plt.xlabel('Gain', fontsize=40)
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Total Gain', fontsize=40)
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[462], line 10
#       8 # Plotting the data as a horizontal bar plot with different colors
#       9 plt.figure(figsize=(43, 14))
# ---> 10 plt.barh(Top_10_geners['genres'], Top_10_geners['vote_count'], color=colors)
#      11 plt.xlabel('Gain', fontsize=40)
#      12 plt.ylabel('Movie Title')
#
# NameError: name 'Top_10_geners' is not defined
